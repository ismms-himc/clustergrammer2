# %%
from clustergrammer_widget import *
net = Network()
net.load_file('rc_two_cats.txt')
net.make_clust()
clustergrammer_widget(network=net.export_net_json())

# %%
# checking ipywidgets version
import ipywidgets as widgets
print(widgets.version_info)
# Out:
# (6, 0, 0, 'beta6')
